# %%
pip install numpy

# %%
pip install pandas

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
cdata = pd.read_csv('/fraudTest.csv')

# %%
cdata.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
cdata
# Out:
#        Unnamed: 0               cc_num                              merchant  \
# 0               0     2291163933867244                 fraud_Kirlin and Sons
# 1               1     3573030041201292                  fraud_Sporer-Keebler
# 2               2     3598215285024754  fraud_Swaniawski, Nitzsche and Welch
# 3               3     3591919803438423                     fraud_Haley Group
# 4               4     3526826139003047                 fraud_Johnston-Casper
# ...           ...                  ...                                   ...
# 50553       50553     2229378226512508                 fraud_Heidenreich PLC
# 50554       50554     2475085306462014                       fraud_Thiel PLC
# 50555       50555      372382441451095                       fraud_Kutch LLC
# 50556       50556  4128730454058057622                    fraud_Luettgen PLC
# 50557       50557     6506982560413523         fraud_Lockman, West and Runte
#
# ...

# %%
cdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50558 entries, 0 to 50557
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  50558 non-null  int64
#  1   cc_num      50558 non-null  int64
#  2   merchant    50558 non-null  object
#  3   category    50558 non-null  object
#  4   amt         50558 non-null  float64
#  5   first       50558 non-null  object
#  6   last        50558 non-null  object
#  7   gender      50558 non-null  object
#  8   street      50558 non-null  object
#  9   city        50558 non-null  object
#  10  state       50558 non-null  object
#  11  zip         50558 non-null  int64
#  12  lat         50558 non-null  float64
#  13  long        50558 non-null  float64
#  14  city_pop    50558 non-null  int64
#  15  job         50558 non-null  object
#  16  dob         50558 non-null  object
#  17  trans_num   50558 non-null  object
#  18  unix_time   50557 non-null  float64
# ...

# %%
cdata.isnull().sum()
# Out:
# Unnamed: 0    0
# cc_num        0
# merchant      0
# category      0
# amt           0
# first         0
# last          0
# gender        0
# street        0
# city          0
# state         0
# zip           0
# lat           0
# long          0
# city_pop      0
# job           0
# dob           0
# trans_num     0
# unix_time     1
# merch_lat     1
# merch_long    1
# is_fraud      1
# dtype: int64

# %%
cdata.value_counts()
# Out:
# Unnamed: 0  cc_num               merchant                              category        amt     first     last      gender  street                      city               state  zip    lat      long       city_pop  job                   dob         trans_num                         unix_time     merch_lat  merch_long   is_fraud
# 0           2291163933867244     fraud_Kirlin and Sons                 personal_care   2.86    Jeff      Elliott   M       351 Darlene Green           Columbia           SC     29209  33.9659  -80.9355   333497    Mechanical engineer   1968-03-19  2da90c7d74bd46a0caf3777415b3ebd3  1.371817e+09  33.986391  -81.200714   0.0         1
# ...

# %%
cdata
# Out:
#        Unnamed: 0               cc_num                              merchant  \
# 0               0     2291163933867244                 fraud_Kirlin and Sons
# 1               1     3573030041201292                  fraud_Sporer-Keebler
# 2               2     3598215285024754  fraud_Swaniawski, Nitzsche and Welch
# 3               3     3591919803438423                     fraud_Haley Group
# 4               4     3526826139003047                 fraud_Johnston-Casper
# ...           ...                  ...                                   ...
# 50553       50553     2229378226512508                 fraud_Heidenreich PLC
# 50554       50554     2475085306462014                       fraud_Thiel PLC
# 50555       50555      372382441451095                       fraud_Kutch LLC
# 50556       50556  4128730454058057622                    fraud_Luettgen PLC
# 50557       50557     6506982560413523         fraud_Lockman, West and Runte
#
# ...

# %%
cdata['is_fraud'].value_counts()
# Out:
# 0.0    50356
# 1.0      201
# Name: is_fraud, dtype: int64

# %%
legit = cdata[cdata.is_fraud == 0]
fraud = cdata[cdata.is_fraud == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (50356, 22)
# (201, 22)

# %%
legit.amt.describe()
# Out:
# count    50356.000000
# mean        67.742018
# std        147.421244
# min          1.000000
# 25%          9.700000
# 50%         46.825000
# 75%         82.240000
# max      13149.150000
# Name: amt, dtype: float64

# %%
cdata.groupby('is_fraud').mean()
# Out:
# <ipython-input-99-0e0b1ce81e3a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cdata.groupby('is_fraud').mean()
#             Unnamed: 0        cc_num         amt           zip        lat  \
# is_fraud
# 0.0       25276.021487  4.141829e+17   67.742018  48725.245889  38.527643
# 1.0       25773.671642  9.282196e+17  497.681393  43032.000000  38.512165
#
#                long      city_pop     unix_time  merch_lat  merch_long
# is_fraud
# 0.0      -90.140923  90865.304889  1.372545e+09  38.525531  -90.139810
# 1.0      -87.376443  76821.552239  1.372558e+09  38.457690  -87.365113

# %%
legit_sample = legit.sample(n=201)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#        Unnamed: 0            cc_num                           merchant  \
# 43696       43696  4642255475285942                  fraud_Gerhold LLC
# 23805       23805  6596735789587928          fraud_Morissette-Schaefer
# 18711       18711  2242542703101233  fraud_Bernier, Streich and Jewess
# 37137       37137  5130484058948421  fraud_Bins, Balistreri and Beatty
# 5834         5834    30238755902988                    fraud_Kuhic LLC
#
#             category     amt     first      last gender  \
# 43696           home   70.22   Sabrina   Johnson      F
# 23805  personal_care   13.69   Spencer  Williams      M
# 18711    grocery_net   16.60    Samuel   Jenkins      M
# 37137   shopping_pos  126.87    Ronald     White      M
# 5834    shopping_net    8.89  Danielle        Yu      F
#
#                               street       city  ...      lat      long  \
# 43696          320 Nicholson Orchard   Thompson  ...  38.9999 -109.6150
# ...

# %%
new_dataset.tail()
# Out:
#        Unnamed: 0            cc_num                  merchant      category  \
# 48140       48140    30197398657930  fraud_Romaguera and Sons        travel
# 48991       48991  4713464490314802  fraud_Stoltenberg-Beatty  shopping_pos
# 49834       49834  4713464490314802     fraud_Bashirian Group  shopping_net
# 50228       50228      503851367360           fraud_Doyle Ltd   grocery_pos
# 50266       50266  4713464490314802      fraud_O'Keefe-Hudson   grocery_pos
#
#            amt   first     last gender                        street  \
# 48140     7.90   April  Johnson      F          9727 Deleon Mountain
# 48991   892.88  Wesley   Parker      M            7452 Browning Port
# 49834  1008.78  Wesley   Parker      M            7452 Browning Port
# 50228   331.18   Bruce     Hall      M  77686 Donald Bridge Apt. 711
# 50266   309.70  Wesley   Parker      M            7452 Browning Port
#
#             city  ...      lat      long  city_pop  \
# ...

# %%
new_dataset['is_fraud'].value_counts()
# Out:
# 0.0    201
# 1.0    201
# Name: is_fraud, dtype: int64

# %%
new_dataset.groupby('is_fraud').mean()
# Out:
# <ipython-input-105-0615df9acffe>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_dataset.groupby('is_fraud').mean()
#             Unnamed: 0        cc_num         amt           zip        lat  \
# is_fraud
# 0.0       24517.606965  2.480137e+17   66.084577  51898.771144  38.139733
# 1.0       25773.671642  9.282196e+17  497.681393  43032.000000  38.512165
#
#                long      city_pop     unix_time  merch_lat  merch_long
# is_fraud
# 0.0      -91.659749  48406.442786  1.372523e+09  38.217499  -91.640884
# 1.0      -87.376443  76821.552239  1.372558e+09  38.457690  -87.365113

# %%
X = new_dataset.drop(columns=['is_fraud','merchant','category','first','last','gender','street','city','job','dob','state','trans_num'], axis=1)
Y = new_dataset['is_fraud']

# %%
print(X)
# Out:
#        Unnamed: 0            cc_num      amt    zip      lat      long  \
# 43696       43696  4642255475285942    70.22  84540  38.9999 -109.6150
# 23805       23805  6596735789587928    13.69  55388  44.9595  -93.8482
# 18711       18711  2242542703101233    16.60  40077  38.4921  -85.4524
# 37137       37137  5130484058948421   126.87  45808  40.8314  -83.9758
# 5834         5834    30238755902988     8.89  76578  30.5920  -97.2893
# ...           ...               ...      ...    ...      ...       ...
# 48140       48140    30197398657930     7.90  27522  36.1124  -78.6476
# 48991       48991  4713464490314802   892.88  57641  45.7084 -101.1546
# 49834       49834  4713464490314802  1008.78  57641  45.7084 -101.1546
# 50228       50228      503851367360   331.18  28530  35.3757  -77.4193
# 50266       50266  4713464490314802   309.70  57641  45.7084 -101.1546
#
#        city_pop     unix_time  merch_lat  merch_long
# 43696        46  1.373113e+09  39.896143 -109.142971
# ...

# %%
print(Y)
# Out:
# 43696    0.0
# 23805    0.0
# 18711    0.0
# 37137    0.0
# 5834     0.0
#         ...
# 48140    1.0
# 48991    1.0
# 49834    1.0
# 50228    1.0
# 50266    1.0
# Name: is_fraud, Length: 402, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (402, 10) (321, 10) (81, 10)

# %%
model = LogisticRegression()

# %%
Y_train = pd.to_numeric(Y_train)

# %%
Y_train.head()
# Out:
# 1781     1.0
# 4141     0.0
# 12045    0.0
# 14064    1.0
# 28302    0.0
# Name: is_fraud, dtype: float64

# %%
print(Y_train)
# Out:
# 1781     1.0
# 4141     0.0
# 12045    0.0
# 14064    1.0
# 28302    0.0
#         ...
# 39021    1.0
# 49211    0.0
# 45204    1.0
# 48991    1.0
# 11347    0.0
# Name: is_fraud, Length: 321, dtype: float64

# %%
Y
# Out:
# 43696    0.0
# 23805    0.0
# 18711    0.0
# 37137    0.0
# 5834     0.0
#         ...
# 48140    1.0
# 48991    1.0
# 49834    1.0
# 50228    1.0
# 50266    1.0
# Name: is_fraud, Length: 402, dtype: float64

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

# %%
print(f"X_train data type: {type(X_train)}")
print(f"Y_train data type: {type(Y_train)}")
# Out:
# X_train data type: <class 'pandas.core.frame.DataFrame'>
# Y_train data type: <class 'pandas.core.series.Series'>

# %%
print(X_train.head())
# Out:
#        Unnamed: 0               cc_num     amt    zip      lat     long  \
# 1781         1781     6564459919350820  620.33  53803  42.5545 -90.3508
# 4141         4141  4092452671396169678   33.75  28423  34.3091 -78.3372
# 12045       12045      349612764943496  144.79  40914  37.1046 -83.5706
# 14064       14064      213161231269724  315.72  35901  34.0480 -85.9246
# 28302       28302     3545109339866548    3.60  38761  33.4783 -90.5142
#
#        city_pop     unix_time  merch_lat  merch_long
# 1781       1306  1.371854e+09  42.771834  -90.158365
# 4141       2290  1.371912e+09  34.153655  -77.597984
# 12045       467  1.372129e+09  36.302588  -84.239922
# 14064     67082  1.372212e+09  34.843287  -85.800046
# 28302      2870  1.372605e+09  33.576331  -90.025524

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.4984423676012461

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.5061728395061729
